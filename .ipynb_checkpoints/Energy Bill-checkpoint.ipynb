# %% [markdown]
# ### OCI Data Science - Useful Tips
# <details>
# <summary><font size="2">Check for Public Internet Access</font></summary>
#
# ```python
# import requests
# response = requests.get("https://oracle.com")
# assert response.status_code==200, "Internet connection failed"
# ```
# </details>
# <details>
# <summary><font size="2">Helpful Documentation </font></summary>
# <ul><li><a href="https://docs.cloud.oracle.com/en-us/iaas/data-science/using/data-science.htm">Data Science Service Documentation</a></li>
# <li><a href="https://docs.cloud.oracle.com/iaas/tools/ads-sdk/latest/index.html">ADS documentation</a></li>
# </ul>
# </details>
# <details>
# <summary><font size="2">Typical Cell Imports and Settings for ADS</font></summary>
#
# ```python
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#
# import warnings
# warnings.filterwarnings('ignore')
#
# import logging
# logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.ERROR)
#
# import ads
# from ads.dataset.factory import DatasetFactory
# from ads.automl.provider import OracleAutoMLProvider
# from ads.automl.driver import AutoML
# from ads.evaluations.evaluator import ADSEvaluator
# from ads.common.data import ADSData
# from ads.explanations.explainer import ADSExplainer
# from ads.explanations.mlx_global_explainer import MLXGlobalExplainer
# from ads.explanations.mlx_local_explainer import MLXLocalExplainer
# from ads.catalog.model import ModelCatalog
# from ads.common.model_artifact import ModelArtifact
# ```
# </details>
# <details>
# <summary><font size="2">Useful Environment Variables</font></summary>
#
# ```python
# import os
# print(os.environ["NB_SESSION_COMPARTMENT_OCID"])
# print(os.environ["PROJECT_OCID"])
# print(os.environ["USER_OCID"])
# print(os.environ["TENANCY_OCID"])
# print(os.environ["NB_REGION"])
# ```
# </details>

# %%
from oci.auth import signers
import oci
import io
import pandas as pd

# Get the resource principal signer
signer = signers.get_resource_principals_signer()

# Create ObjectStorageClient with empty config and the resource principal signer
object_storage_client = oci.object_storage.ObjectStorageClient(config={}, signer=signer)

# Specify your namespace, bucket, and object name (all strings)
namespace = "lr0x98mmd4wz"  # Replace with your actual namespace string
bucket_name = "Energy-Prediction-Dataset"  # Replace with your actual bucket name
object_name = "msoa_final_with_payment_and_labels (1).csv"  # Replace with your actual object name

# Get the object from Object Storage
response = object_storage_client.get_object(namespace, bucket_name, object_name)

# Read object data, for example into a pandas DataFrame (if CSV)
data = response.data.content
df = pd.read_csv(io.BytesIO(data),  low_memory=False)

print(df.head())
# Out:
#   local authority code local authority  msoa code  \
# 0            E06000001      Hartlepool  E02002483
# 1            E06000001      Hartlepool  E02002483
# 2            E06000001      Hartlepool  E02002483
# 3            E06000001      Hartlepool  E02002483
# 4            E06000001      Hartlepool  E02002484
#
#   middle layer super output area number\nof meters total_consumption  \
# 0                 Hartlepool 001             3,743        12,986,912
# 1                 Hartlepool 001             3,743        12,986,912
# 2                 Hartlepool 001             3,743        12,986,912
# 3                 Hartlepool 001             3,743        12,986,912
# 4                 Hartlepool 002             4,802        15,109,783
#
#    mean_consumption median_consumption  year       msoa name  ...  \
# 0            3470.0              3,100  2010  Hartlepool 001  ...
# 1            3470.0              3,100  2010  Hartlepool 001  ...
# ...

# %%
df
# Out:
#        local authority code                  local authority    msoa code  \
# 0                 E06000001                       Hartlepool    E02002483
# 1                 E06000001                       Hartlepool    E02002483
# 2                 E06000001                       Hartlepool    E02002483
# 3                 E06000001                       Hartlepool    E02002483
# 4                 E06000001                       Hartlepool    E02002484
# ...                     ...                              ...          ...
# 287736            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000287
# 287737            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000288
# 287738            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000289
# 287739            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000415
# 287740          Unallocated                      Unallocated  Unallocated
#
#        middle layer super output area number\nof meters total_consumption  \
# ...

# %%
local_file_path = "./" + "msoa_final_with_payment_and_labels (1).csv"  # saves in current directory
with open(local_file_path, 'wb') as f:
    for chunk in response.data.raw.stream(1024 * 1024, decode_content=False):
        f.write(chunk)

print(f"Dataset saved locally to {local_file_path}")
# Out:
# Dataset saved locally to ./msoa_final_with_payment_and_labels (1).csv

# %%
from ads.dataset.factory import DatasetFactory
ds = DatasetFactory.from_dataframe(df).set_target('default_risk_label')
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
ds.show_in_notebook()
# Out:
# Accordion(children=(HTML(value='<h3>Type: BinaryClassificationDataset</h3><h3>287,741 Rows, 25 Columns</h3><h4…

# %%
recommendations = ds.suggest_recommendations()
display(recommendations)
# Out:
#                                                                                                                                                                                             Code
# Message                                                 Variables            Suggested                         Action
# Constant Column                                         label_source         Drop                              Drop                                              .drop_columns(["label_source"])
# Contains missing values(287)                            local_authority_code Fill missing values with frequent Drop                                      .drop_columns(["local_authority_code"])
#                                                                                                                Fill missing values with frequent  .fillna({"local_authority_code": "E08000035"})
# ...

# %%
ds_transformed = ds.auto_transform()
# Out:
# loop1:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
ds.visualize_transforms()

# %%
ds_transformed.visualize_transforms()

# %%
ds_transformed
# Out:
#         <style>
#             .mostly-customized-scrollbar {
#               display: block;
#               width: 100%;
#               overflow: auto;
#             }
#
#             .mostly-customized-scrollbar::-webkit-scrollbar {
#               width: 5px;
#               height: 8px;
#               background-color: #aaa;
#             }
#
#             .mostly-customized-scrollbar::-webkit-scrollbar-thumb {
#                 background: #000;
#                 border-radius: 10px;
#             }
#         </style>
#
#         <div style="width=100%; display: flex; flex-wrap: nowrap; overflow-x: auto;">
#             <div class="mostly-customized-scrollbar">
#                 <style type="text/css">
# #T_ad362 tbody tr:nth-child(even) {
#   background-color: #F8F8F8;
# }
# #T_ad362 tbody tr:hover {
#   background-color: #D9EDFD;
# }
# #T_ad362 th {
#   font-size: 12px;
#   text-align: center;
#   font-weight: bold;
#   background-color: #D3D3D3;
#   padding-left: 5px;
# ...

# %%
import calendar
df_ready = ds_transformed.to_pandas()

# Map month abbreviations to month numbers
month_map = {month: index for index, month in enumerate(calendar.month_abbr) if month}

df_ready['month_num'] = df_ready['quarter'].map(month_map)

# Convert month number to quarter
df_ready['quarter_num'] = ((df_ready['month_num'] - 1) // 3) + 1

# Map quarter_num to seasons
df_ready['season'] = df_ready['quarter_num'].map({1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Autumn'})
df_ready['year_quarter'] = df_ready['year'].astype(str) + 'Q' + df_ready['quarter_num'].astype(str)  # e.g. '2025Q3'

# %%
df_ready
# Out:
#        local_authority_code                  local_authority    msoa_code  \
# 0                 E06000001                       Hartlepool    E02002483
# 1                 E06000001                       Hartlepool    E02002483
# 2                 E06000001                       Hartlepool    E02002483
# 3                 E06000001                       Hartlepool    E02002483
# 4                 E06000001                       Hartlepool    E02002484
# ...                     ...                              ...          ...
# 287736            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000287
# 287737            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000288
# 287738            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000289
# 287739            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000415
# 287740          Unallocated                      Unallocated  Unallocated
#
#        middle_layer_super_output_area total_consumption median_consumption  \
# ...

# %%
df_ready['bill_rolling_4q'] = df_ready.groupby('msoa_code')['annual_bill_estimate'].rolling(window=4, min_periods=1).mean().reset_index(level=0, drop=True)

# %%
df_ready
# Out:
#        local_authority_code                  local_authority    msoa_code  \
# 0                 E06000001                       Hartlepool    E02002483
# 1                 E06000001                       Hartlepool    E02002483
# 2                 E06000001                       Hartlepool    E02002483
# 3                 E06000001                       Hartlepool    E02002483
# 4                 E06000001                       Hartlepool    E02002484
# ...                     ...                              ...          ...
# 287736            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000287
# 287737            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000288
# 287738            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000289
# 287739            W06000024  Merthyr Tydfil / Merthyr Tudful    W02000415
# 287740          Unallocated                      Unallocated  Unallocated
#
#        middle_layer_super_output_area total_consumption median_consumption  \
# ...

# %%
numerical_cols = [
    "total_consumption",
    "median_consumption",
    "total_annual_income",
    "upper_confidence_limit_(£)",
    "lower_confidence_limit_(£)",
    "confidence_interval_(£)",
    "credit_(%)",
    "direct_debit_(%)",
    "prepayment_%",
    "annual_bill_estimate",
    "cost_burden"
]


for col in numerical_cols:
    df_ready[col] = (df_ready[col]
               .astype(str)
               .str.replace(',', '', regex=False)
               .str.replace('£', '', regex=False)
               .str.strip())
    df_ready[col] = pd.to_numeric(df_ready[col], errors='coerce')

# %%
#Consumption Dynamics


df_ready = df_ready.sort_values(by=['msoa_code', 'year', 'quarter_num'])  # Ensure order
df_ready['consumption_yoy'] = df_ready.groupby('msoa_code')['total_consumption'].pct_change(periods=4)  # For quarterly data

# %%
df_ready
# Out:
#        local_authority_code     local_authority  msoa_code  \
# 16356             E09000001      City of London  E02000001
# 16357             E09000001      City of London  E02000001
# 16358             E09000001      City of London  E02000001
# 16359             E09000001      City of London  E02000001
# 38334             E09000001      City of London  E02000001
# ...                     ...                 ...        ...
# 202461            W06000011  Swansea / Abertawe  W02000428
# 223722            W06000011  Swansea / Abertawe  W02000428
# 244983            W06000011  Swansea / Abertawe  W02000428
# 266244            W06000011  Swansea / Abertawe  W02000428
# 287505            W06000011  Swansea / Abertawe  W02000428
#
#        middle_layer_super_output_area  total_consumption  median_consumption  \
# 16356              City of London 001           26802330                3355
# 16357              City of London 001           26802330                3355
# ...

# %%
df_ready['bill_to_consumption'] = df_ready['annual_bill_estimate'] / df_ready['total_consumption']

# %%
df_ready['median_total_ratio'] = df_ready['median_consumption'] / df_ready['total_consumption']

# %%
#Socioeconomic & Burden Features

df_ready['income_bill_ratio'] = df_ready['total_annual_income'] / df_ready['annual_bill_estimate']

# %%
df_ready['cost_burden_band'] = pd.cut(df_ready['cost_burden'], bins=[0, 0.1, 0.2, 0.3, 1],
                                labels=['Low', 'Medium', 'High', 'Very High'])

# %%
msoa_mean = df_ready.groupby('msoa_code')['cost_burden'].transform('mean')
df_ready['relative_cost_burden'] = df_ready['cost_burden'] / msoa_mean

# %%
#Payment Method Signals

df_ready['dominant_payment_mode'] = df_ready[['credit_(%)', 'direct_debit_(%)', 'prepayment_%']].idxmax(axis=1)
df_ready['prepay_volatility'] = df_ready.groupby('msoa_code')['prepayment_%'].transform('std')
df_ready['num_payment_modes'] = df_ready[['credit_(%)', 'direct_debit_(%)', 'prepayment_%']].gt(0).sum(axis=1)

# %%
df_ready
# Out:
#        local_authority_code     local_authority  msoa_code  \
# 16356             E09000001      City of London  E02000001
# 16357             E09000001      City of London  E02000001
# 16358             E09000001      City of London  E02000001
# 16359             E09000001      City of London  E02000001
# 38334             E09000001      City of London  E02000001
# ...                     ...                 ...        ...
# 202461            W06000011  Swansea / Abertawe  W02000428
# 223722            W06000011  Swansea / Abertawe  W02000428
# 244983            W06000011  Swansea / Abertawe  W02000428
# 266244            W06000011  Swansea / Abertawe  W02000428
# 287505            W06000011  Swansea / Abertawe  W02000428
#
#        middle_layer_super_output_area  total_consumption  median_consumption  \
# 16356              City of London 001           26802330                3355
# 16357              City of London 001           26802330                3355
# ...

# %%
from ads.dataset.factory import DatasetFactory


# Set the target label (replace with your actual label column)
ads_ds = DatasetFactory.from_dataframe(df_ready).set_target('default_risk_label')

# Automatically transform the dataset (encoding, scaling, imputation)
ads_ds_transformed = ads_ds.auto_transform()

# Get pandas DataFrame ready for modeling
df_new = ads_ds_transformed.to_pandas()

print("Transformed DataFrame shape:", df_new.shape)
print(df_new.head())
# Out:
# ...
# loop1:   0%|          | 0/7 [00:00<?, ?it/s]
# Transformed DataFrame shape: (287741, 29)
#       local_authority_code local_authority  msoa_code  \
# 16356            E09000001  City of London  E02000001
# 16357            E09000001  City of London  E02000001
# 16358            E09000001  City of London  E02000001
# 16359            E09000001  City of London  E02000001
# 38334            E09000001  City of London  E02000001
#
#       middle_layer_super_output_area  total_consumption  year  \
# 16356             City of London 001           26802330  2010
# 16357             City of London 001           26802330  2010
# 16358             City of London 001           26802330  2010
# 16359             City of London 001           26802330  2010
# 38334             City of London 001           25939246  2011
#
#                 msoa_name local_authority_name region_code region_name  ...  \
# 16356  City of London 001       City of London   E12000007      London  ...
# ...

# %%
df_new
# Out:
#        local_authority_code     local_authority  msoa_code  \
# 16356             E09000001      City of London  E02000001
# 16357             E09000001      City of London  E02000001
# 16358             E09000001      City of London  E02000001
# 16359             E09000001      City of London  E02000001
# 38334             E09000001      City of London  E02000001
# ...                     ...                 ...        ...
# 202461            W06000011  Swansea / Abertawe  W02000428
# 223722            W06000011  Swansea / Abertawe  W02000428
# 244983            W06000011  Swansea / Abertawe  W02000428
# 266244            W06000011  Swansea / Abertawe  W02000428
# 287505            W06000011  Swansea / Abertawe  W02000428
#
#        middle_layer_super_output_area  total_consumption  year  \
# 16356              City of London 001           26802330  2010
# 16357              City of London 001           26802330  2010
# 16358              City of London 001           26802330  2010
# ...

# %%
original_cols = set(df_ready.columns)

# Columns after transformation
transformed_cols = set(df_new.columns)

# Columns dropped by auto_transform
dropped_cols = original_cols - transformed_cols

print("Dropped columns during auto_transform:", dropped_cols)
# Out:
# Dropped columns during auto_transform: {'quarter_num', 'cost_burden_band', 'num_payment_modes', 'bill_rolling_4q', 'bill_to_consumption', 'total_annual_income', 'median_consumption'}

# %%
for col in dropped_cols:
    if pd.api.types.is_numeric_dtype(df_ready[col]):
        corr = df_ready[[col, 'default_risk_label']].corr().iloc[0, 1]
        print(f"{col}: correlation with target = {corr:.3f}")
# Out:
# quarter_num: correlation with target = 0.027
# num_payment_modes: correlation with target = nan
# bill_rolling_4q: correlation with target = 0.040
# bill_to_consumption: correlation with target = 0.000
# total_annual_income: correlation with target = -0.047
# median_consumption: correlation with target = 0.028

# %%
for col in dropped_cols:
    if not pd.api.types.is_numeric_dtype(df_ready[col]):
        print(df_ready.groupby(col)['default_risk_label'].mean())
# Out:
# cost_burden_band
# Low          0.003069
# Medium            NaN
# High              NaN
# Very High         NaN
# Name: default_risk_label, dtype: float64

# %%
df_new.columns
# Out:
# Index(['local_authority_code', 'local_authority', 'msoa_code',
#        'middle_layer_super_output_area', 'total_consumption', 'year',
#        'msoa_name', 'local_authority_name', 'region_code', 'region_name',
#        'upper_confidence_limit_(£)', 'lower_confidence_limit_(£)',
#        'confidence_interval_(£)', 'quarter', 'credit_(%)', 'direct_debit_(%)',
#        'prepayment_%', 'annual_bill_estimate', 'cost_burden',
#        'default_risk_label', 'month_num', 'season', 'year_quarter',
#        'consumption_yoy', 'median_total_ratio', 'income_bill_ratio',
#        'relative_cost_burden', 'dominant_payment_mode', 'prepay_volatility'],
#       dtype='object')

# %%
from ads.dataset.label_encoder import DataFrameLabelEncoder

categorical_cols = [
    'local_authority_code', 'msoa_code', 'region_code',
    'season', 'dominant_payment_mode'
]


df_encoded = DataFrameLabelEncoder().fit_transform(df_new[categorical_cols])

# %%
df_encoded
# Out:
#         local_authority_code  msoa_code  region_code  season  \
# 16356                    280          0            6       3
# 16357                    280          0            6       1
# 16358                    280          0            6       2
# 16359                    280          0            6       0
# 38334                    280          0            6       3
# ...                      ...        ...          ...     ...
# 202461                   355       8664            7       1
# 223722                   355       8664            7       1
# 244983                   355       8664            7       1
# 266244                   355       8664            7       1
# 287505                   355       8664            7       1
#
#         dominant_payment_mode
# 16356                       0
# 16357                       0
# 16358                       0
# 16359                       0
# 38334                       0
# ...                       ...
# ...

# %%
df_remaining = df_new.drop(columns=categorical_cols)

# %%
df_final = pd.concat([df_remaining.reset_index(drop=True),
                      df_encoded.reset_index(drop=True)], axis=1)

# %%
df_final
# Out:
#            local_authority middle_layer_super_output_area  total_consumption  \
# 0           City of London             City of London 001           26802330
# 1           City of London             City of London 001           26802330
# 2           City of London             City of London 001           26802330
# 3           City of London             City of London 001           26802330
# 4           City of London             City of London 001           25939246
# ...                    ...                            ...                ...
# 287736  Swansea / Abertawe                    Swansea 032           15108078
# 287737  Swansea / Abertawe                    Swansea 032           15938882
# 287738  Swansea / Abertawe                    Swansea 032           14750307
# 287739  Swansea / Abertawe                    Swansea 032           13140522
# 287740  Swansea / Abertawe                    Swansea 032           13959869
#
# ...

# %%
# Columns we decided to drop
cols_to_drop = [
    'local_authority', 'middle_layer_super_output_area', 'msoa_name',
    'local_authority_name', 'region_name', 'quarter'             # drop if keeping region_name
]

# Drop only if the columns exist in the DataFrame
df_final = df_final.drop(columns=[c for c in cols_to_drop if c in df.columns])

print("✅ Columns dropped. Remaining columns are:")
print(df.columns.tolist())
# Out:
# ✅ Columns dropped. Remaining columns are:
# ['local_authority_code', 'local_authority', 'msoa_code', 'middle_layer_super_output_area', 'number\nof_meters', 'total_consumption', 'mean_consumption', 'median_consumption', 'year', 'msoa_name', 'local_authority_name', 'region_code', 'region_name', 'total_annual_income', 'upper_confidence_limit_(£)', 'lower_confidence_limit_(£)', 'confidence_interval_(£)', 'quarter', 'credit_(%)', 'direct_debit_(%)', 'prepayment_%', 'annual_bill_estimate', 'cost_burden', 'default_risk_label', 'label_source']

# %%
df_final
# Out:
#         total_consumption  year  upper_confidence_limit_(£)  \
# 0                26802330  2010                      127500
# 1                26802330  2010                      127500
# 2                26802330  2010                      127500
# 3                26802330  2010                      127500
# 4                25939246  2011                      127500
# ...                   ...   ...                         ...
# 287736           15108078  2019                       53300
# 287737           15938882  2020                       53300
# 287738           14750307  2021                       53300
# 287739           13140522  2022                       53300
# 287740           13959869  2023                       53300
#
#         lower_confidence_limit_(£)  confidence_interval_(£)  credit_(%)  \
# 0                            81300                    46200        43.0
# 1                            81300                    46200        43.0
# ...

# %%
numerical_cols = [
    'total_consumption', 'upper_confidence_limit_(£)',
    'lower_confidence_limit_(£)', 'confidence_interval_(£)',
    'credit_(%)', 'direct_debit_(%)', 'prepayment_%',
    'annual_bill_estimate', 'cost_burden',
    'consumption_yoy', 'median_total_ratio', 'income_bill_ratio',
    'relative_cost_burden', 'prepay_volatility'
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_final[numerical_cols] = scaler.fit_transform(df_final[numerical_cols])

# %%
df_final.columns
# Out:
# Index(['total_consumption', 'year', 'upper_confidence_limit_(£)',
#        'lower_confidence_limit_(£)', 'confidence_interval_(£)', 'credit_(%)',
#        'direct_debit_(%)', 'prepayment_%', 'annual_bill_estimate',
#        'cost_burden', 'default_risk_label', 'month_num', 'year_quarter',
#        'consumption_yoy', 'median_total_ratio', 'income_bill_ratio',
#        'relative_cost_burden', 'prepay_volatility', 'local_authority_code',
#        'msoa_code', 'region_code', 'season', 'dominant_payment_mode'],
#       dtype='object')

# %%
ads_ds_cleaned = DatasetFactory.from_dataframe(df_final)
ads_ds_cleaned = ads_ds_cleaned.set_target("default_risk_label")
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
ads_ds_cleaned
# Out:
#         <style>
#             .mostly-customized-scrollbar {
#               display: block;
#               width: 100%;
#               overflow: auto;
#             }
#
#             .mostly-customized-scrollbar::-webkit-scrollbar {
#               width: 5px;
#               height: 8px;
#               background-color: #aaa;
#             }
#
#             .mostly-customized-scrollbar::-webkit-scrollbar-thumb {
#                 background: #000;
#                 border-radius: 10px;
#             }
#         </style>
#
#         <div style="width=100%; display: flex; flex-wrap: nowrap; overflow-x: auto;">
#             <div class="mostly-customized-scrollbar">
#                 <style type="text/css">
# #T_8b832 tbody tr:nth-child(even) {
#   background-color: #F8F8F8;
# }
# #T_8b832 tbody tr:hover {
#   background-color: #D9EDFD;
# }
# #T_8b832 th {
#   font-size: 12px;
#   text-align: center;
#   font-weight: bold;
#   background-color: #D3D3D3;
#   padding-left: 5px;
# ...

# %%
from ads.dataset.helper import up_sample
ds_upsampled = up_sample(ads_ds_cleaned, ['default_risk_label'], sampler = 'default', feature_types= None)
ds_upsampled.head
# Out:
# <bound method NDFrame.head of         total_consumption  year  upper_confidence_limit_(£)  \
# 0                3.563551  2010                    5.263086
# 1                3.563551  2010                    5.263086
# 2                3.563551  2010                    5.263086
# 3                3.563551  2010                    5.263086
# 4                3.347243  2011                    5.263086
# ...                   ...   ...                         ...
# 573711           0.784654  2010                    1.087520
# 573712          -0.421638  2018                   -1.479789
# 573713          -0.691154  2018                   -1.856032
# 573714          -0.406547  2018                   -1.819146
# 573715          -1.185350  2018                   -1.811768
#
#         lower_confidence_limit_(£)  confidence_interval_(£)  credit_(%)  \
# 0                         4.328561                 7.006066    2.742720
# ...

# %%
ds_upsampled[""].value_counts()
# Out:
# 0    286858
# 1    286858
# Name: count, dtype: int64

# %%
ds_upsampled = ds_upsampled.rename(columns={"": "default_risk_label"})

# %%
ads_ds_balanced = DatasetFactory.from_dataframe(ds_upsampled).set_target('default_risk_label')
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
ads_ds_balanced
# Out:
#         <style>
#             .mostly-customized-scrollbar {
#               display: block;
#               width: 100%;
#               overflow: auto;
#             }
#
#             .mostly-customized-scrollbar::-webkit-scrollbar {
#               width: 5px;
#               height: 8px;
#               background-color: #aaa;
#             }
#
#             .mostly-customized-scrollbar::-webkit-scrollbar-thumb {
#                 background: #000;
#                 border-radius: 10px;
#             }
#         </style>
#
#         <div style="width=100%; display: flex; flex-wrap: nowrap; overflow-x: auto;">
#             <div class="mostly-customized-scrollbar">
#                 <style type="text/css">
# #T_8073d tbody tr:nth-child(even) {
#   background-color: #F8F8F8;
# }
# #T_8073d tbody tr:hover {
#   background-color: #D9EDFD;
# }
# #T_8073d th {
#   font-size: 12px;
#   text-align: center;
#   font-weight: bold;
#   background-color: #D3D3D3;
#   padding-left: 5px;
# ...

# %%
#Split Data set into Train, Test and Validation

# %%
data_split = ads_ds_balanced.train_validation_test_split( test_size = 0.1, validation_size = 0.1)
train, validation, test = data_split
print(data_split)
# Out:
# (Train Data
# Shape of X:(464709, 22)
# Shape of y:(464709,), Validation Data
# Shape of X:(51635, 22)
# Shape of y:(51635,), Test Data
# Shape of X:(57372, 22)
# Shape of y:(57372,))
